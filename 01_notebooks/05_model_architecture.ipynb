# %%
from ultralytics import YOLO

model = YOLO("runs/detect/smbt_detection5/weights/best.pt")
model.model.info(verbose=True)
# Out:
# Model summary: 129 layers, 11,137,148 parameters, 0 gradients, 28.7 GFLOPs
# (129, 11137148, 0, 28.6534144)

# %%
model.model.info(verbose=True)
# Out:
# Model summary: 129 layers, 11,137,148 parameters, 0 gradients, 28.7 GFLOPs
# (129, 11137148, 0, 28.6534144)

# %%
# !yolo detect val model=runs/detect/smbt_detection5/weights/best.pt data=../02_dataset/data.yaml imgsz=640 plots=True
# Out:
# Ultralytics 8.3.251  Python-3.11.9 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# Model summary (fused): 72 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 3097.9597.5 MB/s, size: 3044.0 KB)
#
# val: Scanning C:\Users\sveto\OneDrive\Desktop\DL_OBJECT_DETECTION\02_dataset\labels\val.cache... 13 images, 0 backgrounds, 4 corrupt: 100% ━━━━━━━━━━━━ 13/13  0.0s
# val: Scanning C:\Users\sveto\OneDrive\Desktop\DL_OBJECT_DETECTION\02_dataset\labels\val.cache... 13 images, 0 backgrounds, 4 corrupt: 100% ━━━━━━━━━━━━ 13/13  0.0s
# val: C:\Users\sveto\OneDrive\Desktop\DL_OBJECT_DETECTION\02_dataset\images\val\529fbbc8-IMG_2378.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0415287 1.0109149]
# ...
